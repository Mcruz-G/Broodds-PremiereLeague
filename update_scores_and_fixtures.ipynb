# %%
import pandas as pd
import sqlite3
import time
from decimal import Decimal
import re
import numpy as np

# %%
# Out:
# {'Manchester City': 'Manchester_City',
#  'Liverpool': 'Liverpool',
#  'Aston Villa': 'Aston_Villa',
#  'Arsenal': 'Arsenal',
#  'Chelsea': 'Chelsea',
#  'Newcastle Utd': 'Newcastle_United',
#  'Brighton': 'Brighton_and_Hove_Albion',
#  "Nott'ham Forest": 'Nottingham_Forest',
#  'Fulham': 'Fulham',
#  'Tottenham': 'Tottenham_Hotspur',
#  'Manchester Utd': 'Manchester_United',
#  'Brentford': 'Brentford',
#  'Bournemouth': 'Bournemouth',
#  'West Ham': 'West_Ham_United',
#  'Leicester City': 'Leicester_City',
#  'Crystal Palace': 'Crystal_Palace',
#  'Ipswich Town': 'Ipswic_Town',
#  'Southampton': 'Southampton',
#  'Everton': 'Everton',
#  'Wolves': 'Wolverhampton_Wanderers'}

# %%
def clean_and_convert_to_int(x):
    # Convert the item to a string (in case it's not already)
    item_str = str(x)
    # Use regex to remove all non-numeric characters
    cleaned_item = re.sub(r'\D', '', item_str)
    # If there's a valid numeric string, convert it to an integer
    return cleaned_item
# Define a function to determine the SeasonStage
def determine_season_stage(date, round_info):
    if "Apertura" in round_info and "Regular Season" in round_info:
        return "Apertura"
    elif "Clausura" in round_info and "Regular Season" in round_info:
        return "Clausura"
    elif "Guardianes" in round_info:
        return "Guardianes"
    else:
        return "Liguilla"

# Define a function to extract the year
def extract_year(round_info, date):
    if "Quarter-finals" in round_info or "Semi-finals" in round_info or "Repechaje" or "Reclasificacion" in round_info or "Finals" in round_info:
        year = pd.to_datetime(date).year
        year = str(year)
        return year
    return ''.join(filter(str.isdigit, round_info))

# Define a function to determine the Season Type
def determine_season_type(round_info):
    if len(round_info.split('— ')) > 1:
        return round_info.split('— ')[-1]
    if len(round_info.split(' ')) > 1:
        return round_info.split(' ')[-2] + " " + round_info.split(' ')[-1]
    return round_info.split(' ')[-1]

# Función para extraer la temporada del enlace
def extraer_temporada(link):
    temporada = link.split('/')[-2]
    return temporada

def fbref_pull_and_store_data(metadata):
    # Procesar cada fila y actualizar/crear bases de datos SQL
    # complete this ditionary with the metadata of the tables you want to update
    unique_teams  = metadata.MetaEquipo.unique().tolist()
    datos_equipo = []  # Inicializar el DataFrame para los datos del equipo
    data_dict = {x : metadata[metadata.MetaEquipo == x] for x in unique_teams}

    for _, grupo in data_dict.items():
        print(f"Procesando base de datos: ")

        for _, fila in grupo.iterrows():
            tabla_nombre = fila['Tabla']
            link = fila['Link']
            metaequipo = fila['MetaEquipo']
            temporada = extraer_temporada(link) 

            print(f"Descargando datos de {tabla_nombre}, {metaequipo}.{temporada} desde {link}")
            
            time.sleep(3)  # Espera 1 segundo entre cada solicitud
            try:
                datos_tabla = pd.read_html(link)
            
                datos_tabla = datos_tabla[1]
                datos_tabla['Temporada'] = temporada  # Agregar la temporada como columna
                datos_tabla['MetaEquipo'] = metaequipo
                datos_equipo.append(datos_tabla)

            except:
                pass
    
    equipos = metadata.Equipo.unique().tolist()
    metaequipos = metadata.MetaEquipo.unique().tolist()
    name_mapping = dict(zip(equipos, metaequipos))

    data = pd.concat(datos_equipo, ignore_index=True, sort=False)
    data = data[data.Opponent.isin(name_mapping.keys())]
    data["Opponent"] = data["Opponent"].apply(lambda row: name_mapping[row])

    return data


def clean_goals(x):
    if type(x) != str:
        if np.isnan(x):
            return 0.0
        if type(x) == int or type(x) == float:
            return int(x)
        else: 
            return Decimal(x)       
    if ( "(" not in x) and ("." not in x):
        return int(x)
    if "(" in x:
        return int(x.split("(")[0])
    if "." in x:
        return int(x.split(".")[0])
    return int(x)
 

def data_cleaning(df):

       
    df['GF'] = df['GF'].apply(lambda x: x if x != None else '0')
    # df['GF'] = df['GF'].apply(lambda x: str(re.sub(r'\D', '', x)))
    df['GF'] = df['GF'].apply(clean_goals)
    df['GF'] = df['GF'].astype('int')

    df['GA'] = df['GA'].apply(lambda x: x if x != None else '0')
    # df['GA'] = df['GA'].apply(lambda x: str(re.sub(r'\D', '', x)))
    df['GA'] = df['GA'].apply(clean_goals)
    df['GA'] = df['GA'].astype('int')
    
    df['xG'] = df['xG'].apply(lambda x: x if x != None else '0')
    df['xG'] = df['xG'].astype(float)

    df['xGA'] = df['xGA'].apply(lambda x: x if x != None else '0')
    df['xGA'] = df['xGA'].astype(float)

    df['xG'] = df['xG'].fillna(0)
    df['xGA'] = df['xGA'].fillna(0)

    return df

def add_current_points(df):
    # Ordena los datos por temporada, seasonstage, Jornada y fecha para asegurar un orden correcto
    df.sort_values(by=['Temporada', 'MetaEquipo', 'Date'], inplace=True)
    # Inicializa las columnas 'current_points', 'current_wins' y 'current_goals' en NaN (espacios vacíos)
    df['current_points'] = ''
    df['current_points_home'] = ''
    df['current_points_away'] = ''
    df['current_exp_points'] = ''
    df['current_exp_points_home'] = ''
    df['current_exp_points_away'] = ''
    df['current_wins'] = ''
    df['current_wins_home'] = ''
    df['current_wins_away'] = ''
    df['current_draws'] = ''
    df['current_draws_home'] = ''
    df['current_draws_away'] = ''
    df['current_losses'] = ''
    df['current_losses_home'] = ''
    df['current_losses_away'] = ''
    df['current_goals'] = ''
    df['current_goals_home'] = ''
    df['current_goals_away'] = ''
    df['current_exp_goals'] = ''
    df['current_exp_goals_away'] = ''
    df['current_exp_goals_home'] = ''
    df['current_goals_against'] = ''
    df['current_goals_against_home'] = ''
    df['current_goals_against_away'] = ''
    df['current_exp_goals_against'] = ''
    df['current_exp_goals_against_home'] = ''
    df['current_exp_goals_against_away'] = ''
    df['current_ranking_points'] = ''
    df['current_ranking_points_home'] = ''
    df['current_ranking_points_away'] = ''
    df['current_ranking_wins'] = ''
    df['current_ranking_wins_home'] = ''
    df['current_ranking_wins_away'] = ''
    df['current_ranking_goals'] = ''
    df['current_ranking_goals_home'] = ''
    df['current_ranking_goals_away'] = ''
    df['current_ranking_score'] = ''
    df['current_ranking_score_home'] = ''
    df['current_ranking_score_away'] = ''
    df['current_goals_difference'] = ''
    df['current_goals_difference_home'] = ''
    df['current_goals_difference_away'] = ''
    df['ranking'] = ''
    df['partidos_jugados'] = ''
    df['partidos_jugados_home'] = ''
    df['partidos_jugados_away'] = ''

    df = df[df.Comp == 'La Liga']

    df['Jornada'] = df['Round'].apply(lambda row: int(row.split(" ")[-1]), axis=1) 

    temporadas = df.Temporada.unique().tolist()
    # stages = ['Apertura','Clausura']
    jornadas = df.Jornada.unique().tolist()

    for temp in temporadas:
        # for stage in stages:
        puntos_acumulados = {}
        puntos_acumulados_home = {}
        puntos_acumulados_away = {}
        exp_puntos_acumulados = {}
        exp_puntos_acumulados_home = {}
        exp_puntos_acumulados_away = {}
        wins_acumulados = {}
        wins_acumulados_home = {}
        wins_acumulados_away = {}
        draws_acumulados = {}
        draws_acumulados_home = {}
        draws_acumulados_away = {}
        losses_acumulados = {}
        losses_acumulados_home = {}
        losses_acumulados_away = {}
        goals_acumulados = {}
        goals_acumulados_home = {}
        goals_acumulados_away = {}
        exp_goals_acumulados = {}
        exp_goals_acumulados_home = {}
        exp_goals_acumulados_away = {}
        goals_against_acumulados = {}
        goals_against_acumulados_home = {}
        goals_against_acumulados_away = {}
        exp_goals_against_acumulados = {}
        exp_goals_against_acumulados_home = {}
        exp_goals_against_acumulados_away = {}
        diferencia_goles_acumulados = {}
        diferencia_goles_acumulados_home = {}
        diferencia_goles_acumulados_away = {}
        partidos_jugados = {}
        partidos_jugados_home = {}
        partidos_jugados_away = {}
        sample = df[(df.Temporada == temp)].sort_values(by='Date')
            
        for index, row in sample.iterrows():
            equipo = row['MetaEquipo']

            # Verifica si el equipo ya está en el diccionario de puntos acumulados
            if equipo not in puntos_acumulados:
                puntos_acumulados[equipo] = 0
                puntos_acumulados_home[equipo] = 0
                puntos_acumulados_away[equipo] = 0
                exp_puntos_acumulados[equipo] = 0
                exp_puntos_acumulados_home[equipo] = 0
                exp_puntos_acumulados_away[equipo] = 0
                wins_acumulados[equipo] = 0
                wins_acumulados_home[equipo] = 0
                wins_acumulados_away[equipo] = 0
                draws_acumulados[equipo] = 0
                draws_acumulados_home[equipo] = 0
                draws_acumulados_away[equipo] = 0
                losses_acumulados[equipo] = 0
                losses_acumulados_home[equipo] = 0
                losses_acumulados_away[equipo] = 0
                goals_acumulados[equipo] = 0
                goals_acumulados_home[equipo] = 0
                goals_acumulados_away[equipo] = 0
                exp_goals_acumulados[equipo] = 0
                exp_goals_acumulados_home[equipo] = 0
                exp_goals_acumulados_away[equipo] = 0
                goals_against_acumulados[equipo] = 0
                goals_against_acumulados_home[equipo] = 0
                goals_against_acumulados_away[equipo] = 0
                exp_goals_against_acumulados[equipo] = 0
                exp_goals_against_acumulados_home[equipo] = 0
                exp_goals_against_acumulados_away[equipo] = 0
                diferencia_goles_acumulados[equipo] = 0
                diferencia_goles_acumulados_home[equipo] = 0
                diferencia_goles_acumulados_away[equipo] = 0
                partidos_jugados[equipo] = 0
                partidos_jugados_home[equipo] = 0
                partidos_jugados_away[equipo] = 0

            # Asigna los puntos según el resultado del partido
            if row['Venue'] == 'Home':
                partidos_jugados_home[equipo] += 1
                goals_acumulados_home[equipo] += row['GF']
                goals_against_acumulados_home[equipo] += row['GA']
                exp_goals_acumulados_home[equipo] += row['xG']
                exp_goals_against_acumulados_home[equipo] += row['xGA']
                diferencia_goles_acumulados_home[equipo] += row['GF'] - row['GA']
            else:
                partidos_jugados_away[equipo] += 1
                goals_acumulados_away[equipo] += row['GF']
                goals_against_acumulados_away[equipo] += row['GA']
                exp_goals_acumulados_away[equipo] += row['xG']
                exp_goals_against_acumulados_away[equipo] += row['xGA']
                diferencia_goles_acumulados_away[equipo] += row['GF'] - row['GA']

            if row['Result'] == 'W':
                puntos_acumulados[equipo] += 3
                wins_acumulados[equipo] += 1
                if row['Venue'] == 'Home':
                    puntos_acumulados_home[equipo] += 3
                    wins_acumulados_home[equipo] += 1
                    
                else:
                    puntos_acumulados_away[equipo] += 3
                    wins_acumulados_away[equipo] += 1


            elif row['Result'] == 'D':
                puntos_acumulados[equipo] += 1
                draws_acumulados[equipo] += 1
                if row['Venue'] == 'Home':
                    puntos_acumulados_home[equipo] += 1
                    draws_acumulados_home[equipo] += 1
                else:
                    puntos_acumulados_away[equipo] += 1
                    draws_acumulados_away[equipo] += 1
            else:
                losses_acumulados[equipo] += 1
                if row['Venue'] == 'Home':
                    losses_acumulados_home[equipo] += 1
                else:
                    losses_acumulados_away[equipo] += 1
            
            if row['Expected_Results'] == "W":
                exp_puntos_acumulados[equipo] += 3
                if row['Venue'] == 'Home':
                    exp_puntos_acumulados_home[equipo] += 3
                else:
                    exp_puntos_acumulados_away[equipo] += 3
            elif row['Expected_Results'] == "D":
                exp_puntos_acumulados[equipo] += 1
                if row['Venue'] == 'Home':
                    exp_puntos_acumulados_home[equipo] += 1
                else:
                    exp_puntos_acumulados_away[equipo] += 1

            # Suma los goles
            partidos_jugados[equipo] += 1
            goals_acumulados[equipo] += row['GF']
            exp_goals_acumulados[equipo] += row['xG']
            goals_against_acumulados[equipo] += row['GA']
            exp_goals_against_acumulados[equipo] += row['xGA']
            diferencia_goles_acumulados[equipo] += row['GF'] - row['GA']

            # Asigna los valores acumulados a las columnas correspondientes
            sample.at[index, 'current_points'] = puntos_acumulados[equipo]
            sample.at[index, 'current_points_home'] = puntos_acumulados_home[equipo]
            sample.at[index, 'current_points_away'] = puntos_acumulados_away[equipo]
            sample.at[index, 'current_exp_points'] = exp_puntos_acumulados[equipo]
            sample.at[index, 'current_exp_points_home'] = exp_puntos_acumulados_home[equipo]
            sample.at[index, 'current_exp_points_away'] = exp_puntos_acumulados_away[equipo]
            sample.at[index, 'current_wins'] = wins_acumulados[equipo]
            sample.at[index, 'current_wins_home'] = wins_acumulados_home[equipo]
            sample.at[index, 'current_wins_away'] = wins_acumulados_away[equipo]
            sample.at[index, 'current_draws'] = draws_acumulados[equipo]
            sample.at[index, 'current_draws_home'] = draws_acumulados_home[equipo]
            sample.at[index, 'current_draws_away'] = draws_acumulados_away[equipo]
            sample.at[index, 'current_losses'] = losses_acumulados[equipo]
            sample.at[index, 'current_losses_home'] = losses_acumulados_home[equipo]
            sample.at[index, 'current_losses_away'] = losses_acumulados_away[equipo]
            sample.at[index, 'current_goals'] = goals_acumulados[equipo]
            sample.at[index, 'current_goals_home'] = goals_acumulados_home[equipo]
            sample.at[index, 'current_goals_away'] = goals_acumulados_away[equipo]
            sample.at[index, 'current_exp_goals'] = exp_goals_acumulados[equipo]
            sample.at[index, 'current_exp_goals_home'] = exp_goals_acumulados_home[equipo]
            sample.at[index, 'current_exp_goals_away'] = exp_goals_acumulados_away[equipo]
            sample.at[index, 'current_goals_against'] = goals_against_acumulados[equipo]
            sample.at[index, 'current_goals_against_home'] = goals_against_acumulados_home[equipo]
            sample.at[index, 'current_goals_against_away'] = goals_against_acumulados_away[equipo]
            sample.at[index, 'current_exp_goals_against'] = exp_goals_against_acumulados[equipo]
            sample.at[index, 'current_exp_goals_against_home'] = exp_goals_against_acumulados_home[equipo]
            sample.at[index, 'current_exp_goals_against_away'] = exp_goals_against_acumulados_away[equipo]
            sample.at[index, 'current_goals_difference'] = diferencia_goles_acumulados[equipo]
            sample.at[index, 'current_goals_difference_home'] = diferencia_goles_acumulados_home[equipo]
            sample.at[index, 'current_goals_difference_away'] = diferencia_goles_acumulados_away[equipo]
            sample.at[index, 'partidos_jugados'] = partidos_jugados[equipo]
            sample.at[index, 'partidos_jugados_home'] = partidos_jugados_home[equipo]
            sample.at[index, 'partidos_jugados_away'] = partidos_jugados_away[equipo]
        

        for jornada in jornadas:
            subsample = sample[sample.Jornada == jornada]
            subsample.sort_values(by=['current_points','current_goals_difference','current_goals'], inplace=True, ascending=False)
            subsample['ranking'] = range(1,len(subsample) + 1)
            sample.loc[subsample.index] = subsample
            
        df.loc[sample.index] = sample
    

    aux_df = df[['Date','MetaEquipo','ranking']]
    aux_df = aux_df.rename(columns={'MetaEquipo':'Opponent', 'ranking':'opponent_ranking'})

    df = df.merge(aux_df, on=['Date','Opponent'], how='left')
    return df

def add_columns(df):

    df['TotalGoals'] = df['GF'] + df['GA']
    df['GoalsDifference'] = df['GF'] - df['GA']
    df['AA'] = df.apply(lambda row: 1 if row['GF'] > 0 and row['GA'] > 0 else 0, axis=1)


    df['Expected_GF'] = df['xG'].apply(lambda x: round(x))
    df['Expected_GA'] = df['xGA'].apply(lambda x: round(x))

    # Write the column "Expected_Results" Which is "W" if round(xG) > round(xGA), "D" if round(xG) == round(xGA) and "L" if round(xG) < round(xGA)
    df['Expected_Results'] = df.apply(lambda row: 'W' if row['Expected_GF'] > row['Expected_GA'] else 'D' if row['Expected_GF'] == row['Expected_GA'] else 'L', axis=1)
    df['Expected_Goals_Difference'] = df['Expected_GF'] - df['Expected_GA']

    df['match_points'] = df.apply(lambda row: 3 if row['Result'] == 'W' else 1 if row['Result'] == 'D' else 0, axis=1)
    df['match_expected_points'] = df.apply(lambda row: 3 if row['Expected_Results'] == 'W' else 1 if row['Result'] == 'D' else 0, axis=1)
    df = add_current_points(df)
    return df

# %%
metadata = pd.read_csv("data/csvdata/metadata.csv")
metadata['Temporada'] = metadata.apply(lambda row: row['Link'].split('/')[-2], axis=1)

retrieved_data = fbref_pull_and_store_data(metadata)

# retrieved_data = data_cleaning(retrieved_data)
# retrieved_data = add_columns(retrieved_data)

# print(retrieved_data.columns)

# db_path = "data/sqldata/Historic_scores_and_fixtures.db"

# conn = sqlite3.connect(db_path)

# current_total_data = pd.read_sql_query("SELECT * FROM scores_and_fixture", conn)
# # current_total_data = pd.read_csv('data/csvdata/scores_and_fixtures.csv')
# current_total_data = current_total_data[~current_total_data.Temporada.isin([season])]

# new_data = pd.concat([current_total_data, retrieved_data], ignore_index=True, sort=False)
# new_data.to_sql('scores_and_fixture', conn, if_exists='replace', index=False)
# new_data.to_csv('data/csvdata/scores_and_fixtures.csv')
# Out:
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Manchester_City.2024-2025 desde https://fbref.com/en/squads/b8fd03ef/2024-2025/Manchester-City-Stat
# Descargando datos de scores_and_fixtures, Manchester_City.2023-2024 desde https://fbref.com/en/squads/b8fd03ef/2023-2024/Manchester-City-Stat
# Descargando datos de scores_and_fixtures, Manchester_City.2022-2023 desde https://fbref.com/en/squads/b8fd03ef/2022-2023/Manchester-City-Stat
# Descargando datos de scores_and_fixtures, Manchester_City.2021-2022 desde https://fbref.com/en/squads/b8fd03ef/2021-2022/Manchester-City-Stat
# Descargando datos de scores_and_fixtures, Manchester_City.2020-2021 desde https://fbref.com/en/squads/b8fd03ef/2020-2021/Manchester-City-Stat
# Descargando datos de scores_and_fixtures, Manchester_City.2019-2020 desde https://fbref.com/en/squads/b8fd03ef/2019-2020/Manchester-City-Stat
# Descargando datos de scores_and_fixtures, Manchester_City.2018-2019 desde https://fbref.com/en/squads/b8fd03ef/2018-2019/Manchester-City-Stat
# Descargando datos de scores_and_fixtures, Manchester_City.2017-2018 desde https://fbref.com/en/squads/b8fd03ef/2017-2018/Manchester-City-Stat
# Descargando datos de scores_and_fixtures, Manchester_City.2016-2017 desde https://fbref.com/en/squads/b8fd03ef/2016-2017/Manchester-City-Stat
# Descargando datos de scores_and_fixtures, Manchester_City.2015-2016 desde https://fbref.com/en/squads/b8fd03ef/2015-2016/Manchester-City-Stat
# Descargando datos de scores_and_fixtures, Manchester_City.2014-2015 desde https://fbref.com/en/squads/b8fd03ef/2014-2015/Manchester-City-Stat
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Liverpool.2024-2025 desde https://fbref.com/en/squads/822bd0ba/2024-2025/Liverpool-Stats
# Descargando datos de scores_and_fixtures, Liverpool.2023-2024 desde https://fbref.com/en/squads/822bd0ba/2023-2024/Liverpool-Stats
# Descargando datos de scores_and_fixtures, Liverpool.2022-2023 desde https://fbref.com/en/squads/822bd0ba/2022-2023/Liverpool-Stats
# Descargando datos de scores_and_fixtures, Liverpool.2021-2022 desde https://fbref.com/en/squads/822bd0ba/2021-2022/Liverpool-Stats
# Descargando datos de scores_and_fixtures, Liverpool.2020-2021 desde https://fbref.com/en/squads/822bd0ba/2020-2021/Liverpool-Stats
# Descargando datos de scores_and_fixtures, Liverpool.2019-2020 desde https://fbref.com/en/squads/822bd0ba/2019-2020/Liverpool-Stats
# Descargando datos de scores_and_fixtures, Liverpool.2018-2019 desde https://fbref.com/en/squads/822bd0ba/2018-2019/Liverpool-Stats
# Descargando datos de scores_and_fixtures, Liverpool.2017-2018 desde https://fbref.com/en/squads/822bd0ba/2017-2018/Liverpool-Stats
# Descargando datos de scores_and_fixtures, Liverpool.2016-2017 desde https://fbref.com/en/squads/822bd0ba/2016-2017/Liverpool-Stats
# Descargando datos de scores_and_fixtures, Liverpool.2015-2016 desde https://fbref.com/en/squads/822bd0ba/2015-2016/Liverpool-Stats
# Descargando datos de scores_and_fixtures, Liverpool.2014-2015 desde https://fbref.com/en/squads/822bd0ba/2014-2015/Liverpool-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Aston_Villa.2024-2025 desde https://fbref.com/en/squads/8602292d/2024-2025/Aston-Villa-Stats
# Descargando datos de scores_and_fixtures, Aston_Villa.2023-2024 desde https://fbref.com/en/squads/8602292d/2023-2024/Aston-Villa-Stats
# Descargando datos de scores_and_fixtures, Aston_Villa.2022-2023 desde https://fbref.com/en/squads/8602292d/2022-2023/Aston-Villa-Stats
# Descargando datos de scores_and_fixtures, Aston_Villa.2021-2022 desde https://fbref.com/en/squads/8602292d/2021-2022/Aston-Villa-Stats
# Descargando datos de scores_and_fixtures, Aston_Villa.2020-2021 desde https://fbref.com/en/squads/8602292d/2020-2021/Aston-Villa-Stats
# Descargando datos de scores_and_fixtures, Aston_Villa.2019-2020 desde https://fbref.com/en/squads/8602292d/2019-2020/Aston-Villa-Stats
# Descargando datos de scores_and_fixtures, Aston_Villa.2018-2019 desde https://fbref.com/en/squads/8602292d/2018-2019/Aston-Villa-Stats
# Descargando datos de scores_and_fixtures, Aston_Villa.2017-2018 desde https://fbref.com/en/squads/8602292d/2017-2018/Aston-Villa-Stats
# Descargando datos de scores_and_fixtures, Aston_Villa.2016-2017 desde https://fbref.com/en/squads/8602292d/2016-2017/Aston-Villa-Stats
# Descargando datos de scores_and_fixtures, Aston_Villa.2015-2016 desde https://fbref.com/en/squads/8602292d/2015-2016/Aston-Villa-Stats
# Descargando datos de scores_and_fixtures, Aston_Villa.2014-2015 desde https://fbref.com/en/squads/8602292d/2014-2015/Aston-Villa-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Arsenal.2024-2025 desde https://fbref.com/en/squads/18bb7c10/2024-2025/Arsenal-Stats
# Descargando datos de scores_and_fixtures, Arsenal.2023-2024 desde https://fbref.com/en/squads/18bb7c10/2023-2024/Arsenal-Stats
# Descargando datos de scores_and_fixtures, Arsenal.2022-2023 desde https://fbref.com/en/squads/18bb7c10/2022-2023/Arsenal-Stats
# Descargando datos de scores_and_fixtures, Arsenal.2021-2020 desde https://fbref.com/en/squads/18bb7c10/2021-2020/Arsenal-Stats
# Descargando datos de scores_and_fixtures, Arsenal.2020-2021 desde https://fbref.com/en/squads/18bb7c10/2020-2021/Arsenal-Stats
# Descargando datos de scores_and_fixtures, Arsenal.2019-2020 desde https://fbref.com/en/squads/18bb7c10/2019-2020/Arsenal-Stats
# Descargando datos de scores_and_fixtures, Arsenal.2018-2019 desde https://fbref.com/en/squads/18bb7c10/2018-2019/Arsenal-Stats
# Descargando datos de scores_and_fixtures, Arsenal.2017-2018 desde https://fbref.com/en/squads/18bb7c10/2017-2018/Arsenal-Stats
# Descargando datos de scores_and_fixtures, Arsenal.2016-2017 desde https://fbref.com/en/squads/18bb7c10/2016-2017/Arsenal-Stats
# Descargando datos de scores_and_fixtures, Arsenal.2015-2016 desde https://fbref.com/en/squads/18bb7c10/2015-2016/Arsenal-Stats
# Descargando datos de scores_and_fixtures, Arsenal.2014-2015 desde https://fbref.com/en/squads/18bb7c10/2014-2015/Arsenal-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Chelsea.2024-2025 desde https://fbref.com/en/squads/cff3d9bb/2024-2025/Chelsea-Stats
# Descargando datos de scores_and_fixtures, Chelsea.2023-2024 desde https://fbref.com/en/squads/cff3d9bb/2023-2024/Chelsea-Stats
# Descargando datos de scores_and_fixtures, Chelsea.2022-2023 desde https://fbref.com/en/squads/cff3d9bb/2022-2023/Chelsea-Stats
# Descargando datos de scores_and_fixtures, Chelsea.2021-2022 desde https://fbref.com/en/squads/cff3d9bb/2021-2022/Chelsea-Stats
# Descargando datos de scores_and_fixtures, Chelsea.2020-2021 desde https://fbref.com/en/squads/cff3d9bb/2020-2021/Chelsea-Stats
# Descargando datos de scores_and_fixtures, Chelsea.2019-2020 desde https://fbref.com/en/squads/cff3d9bb/2019-2020/Chelsea-Stats
# Descargando datos de scores_and_fixtures, Chelsea.2018-2019 desde https://fbref.com/en/squads/cff3d9bb/2018-2019/Chelsea-Stats
# Descargando datos de scores_and_fixtures, Chelsea.2017-2018 desde https://fbref.com/en/squads/cff3d9bb/2017-2018/Chelsea-Stats
# Descargando datos de scores_and_fixtures, Chelsea.2016-2017 desde https://fbref.com/en/squads/cff3d9bb/2016-2017/Chelsea-Stats
# Descargando datos de scores_and_fixtures, Chelsea.2015-2016 desde https://fbref.com/en/squads/cff3d9bb/2015-2016/Chelsea-Stats
# Descargando datos de scores_and_fixtures, Chelsea.2014-2015 desde https://fbref.com/en/squads/cff3d9bb/2014-2015/Chelsea-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Newcastle_United.2024-2025 desde https://fbref.com/en/squads/b2b47a98/2024-2025/Newcastle-United-Stats
# Descargando datos de scores_and_fixtures, Newcastle_United.2023-2024 desde https://fbref.com/en/squads/b2b47a98/2023-2024/Newcastle-United-Stats
# Descargando datos de scores_and_fixtures, Newcastle_United.2022-2023 desde https://fbref.com/en/squads/b2b47a98/2022-2023/Newcastle-United-Stats
# Descargando datos de scores_and_fixtures, Newcastle_United.2021-2022 desde https://fbref.com/en/squads/b2b47a98/2021-2022/Newcastle-United-Stats
# Descargando datos de scores_and_fixtures, Newcastle_United.2020-2021 desde https://fbref.com/en/squads/b2b47a98/2020-2021/Newcastle-United-Stats
# Descargando datos de scores_and_fixtures, Newcastle_United.2019-2020 desde https://fbref.com/en/squads/b2b47a98/2019-2020/Newcastle-United-Stats
# Descargando datos de scores_and_fixtures, Newcastle_United.2018-2019 desde https://fbref.com/en/squads/b2b47a98/2018-2019/Newcastle-United-Stats
# Descargando datos de scores_and_fixtures, Newcastle_United.2017-2018 desde https://fbref.com/en/squads/b2b47a98/2017-2018/Newcastle-United-Stats
# Descargando datos de scores_and_fixtures, Newcastle_United.2016-2017 desde https://fbref.com/en/squads/b2b47a98/2016-2017/Newcastle-United-Stats
# Descargando datos de scores_and_fixtures, Newcastle_United.2015-2016 desde https://fbref.com/en/squads/b2b47a98/2015-2016/Newcastle-United-Stats
# Descargando datos de scores_and_fixtures, Newcastle_United.2014-2015 desde https://fbref.com/en/squads/b2b47a98/2014-2015/Newcastle-United-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2024-2025 desde https://fbref.com/en/squads/d07537b9/2024-2025/Brighton-and-Hove-Albion-Stats
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2023-2024 desde https://fbref.com/en/squads/d07537b9/2023-2024/Brighton-and-Hove-Albion-Stats
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2022-2023 desde https://fbref.com/en/squads/d07537b9/2022-2023/Brighton-and-Hove-Albion-Stats
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2021-2022 desde https://fbref.com/en/squads/d07537b9/2021-2022/Brighton-and-Hove-Albion-Stats
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2020-2021 desde https://fbref.com/en/squads/d07537b9/2020-2021/Brighton-and-Hove-Albion-Stats
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2019-2020 desde https://fbref.com/en/squads/d07537b9/2019-2020/Brighton-and-Hove-Albion-Stats
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2018-2019 desde https://fbref.com/en/squads/d07537b9/2018-2019/Brighton-and-Hove-Albion-Stats
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2017-2018 desde https://fbref.com/en/squads/d07537b9/2017-2018/Brighton-and-Hove-Albion-Stats
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2016-2017 desde https://fbref.com/en/squads/d07537b9/2016-2017/Brighton-and-Hove-Albion-Stats
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2015-2016 desde https://fbref.com/en/squads/d07537b9/2015-2016/Brighton-and-Hove-Albion-Stats
# Descargando datos de scores_and_fixtures, Brighton_and_Hove_Albion.2014-2015 desde https://fbref.com/en/squads/d07537b9/2014-2015/Brighton-and-Hove-Albion-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2024-2025 desde https://fbref.com/en/squads/e4a775cb/2024-2025/Nottingham-Forest-Stats
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2023-2024 desde https://fbref.com/en/squads/e4a775cb/2023-2024/Nottingham-Forest-Stats
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2022-2023 desde https://fbref.com/en/squads/e4a775cb/2022-2023/Nottingham-Forest-Stats
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2021-2022 desde https://fbref.com/en/squads/e4a775cb/2021-2022/Nottingham-Forest-Stats
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2020-2021 desde https://fbref.com/en/squads/e4a775cb/2020-2021/Nottingham-Forest-Stats
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2019-2020 desde https://fbref.com/en/squads/e4a775cb/2019-2020/Nottingham-Forest-Stats
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2018-2019 desde https://fbref.com/en/squads/e4a775cb/2018-2019/Nottingham-Forest-Stats
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2017-2018 desde https://fbref.com/en/squads/e4a775cb/2017-2018/Nottingham-Forest-Stats
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2016-2017 desde https://fbref.com/en/squads/e4a775cb/2016-2017/Nottingham-Forest-Stats
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2015-2016 desde https://fbref.com/en/squads/e4a775cb/2015-2016/Nottingham-Forest-Stats
# Descargando datos de scores_and_fixtures, Nottingham_Forest.2014-2015 desde https://fbref.com/en/squads/e4a775cb/2014-2015/Nottingham-Forest-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Fulham.2024-2025 desde https://fbref.com/en/squads/fd962109/2024-2025/Fulham-Stats
# Descargando datos de scores_and_fixtures, Fulham.2023-2024 desde https://fbref.com/en/squads/fd962109/2023-2024/Fulham-Stats
# Descargando datos de scores_and_fixtures, Fulham.2022-2023 desde https://fbref.com/en/squads/fd962109/2022-2023/Fulham-Stats
# Descargando datos de scores_and_fixtures, Fulham.2021-2022 desde https://fbref.com/en/squads/fd962109/2021-2022/Fulham-Stats
# Descargando datos de scores_and_fixtures, Fulham.2020-2021 desde https://fbref.com/en/squads/fd962109/2020-2021/Fulham-Stats
# Descargando datos de scores_and_fixtures, Fulham.2019-2020 desde https://fbref.com/en/squads/fd962109/2019-2020/Fulham-Stats
# Descargando datos de scores_and_fixtures, Fulham.2018-2019 desde https://fbref.com/en/squads/fd962109/2018-2019/Fulham-Stats
# Descargando datos de scores_and_fixtures, Fulham.2017-2018 desde https://fbref.com/en/squads/fd962109/2017-2018/Fulham-Stats
# Descargando datos de scores_and_fixtures, Fulham.2016-2017 desde https://fbref.com/en/squads/fd962109/2016-2017/Fulham-Stats
# Descargando datos de scores_and_fixtures, Fulham.2015-2016 desde https://fbref.com/en/squads/fd962109/2015-2016/Fulham-Stats
# Descargando datos de scores_and_fixtures, Fulham.2014-2015 desde https://fbref.com/en/squads/fd962109/2014-2015/Fulham-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2024-2025 desde https://fbref.com/en/squads/361ca564/2024-2025/Tottenham-Hotspur-Stats
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2023-2024 desde https://fbref.com/en/squads/361ca564/2023-2024/Tottenham-Hotspur-Stats
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2022-2023 desde https://fbref.com/en/squads/361ca564/2022-2023/Tottenham-Hotspur-Stats
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2021-2022 desde https://fbref.com/en/squads/361ca564/2021-2022/Tottenham-Hotspur-Stats
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2020-2021 desde https://fbref.com/en/squads/361ca564/2020-2021/Tottenham-Hotspur-Stats
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2019-2020 desde https://fbref.com/en/squads/361ca564/2019-2020/Tottenham-Hotspur-Stats
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2018-2019 desde https://fbref.com/en/squads/361ca564/2018-2019/Tottenham-Hotspur-Stats
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2017-2018 desde https://fbref.com/en/squads/361ca564/2017-2018/Tottenham-Hotspur-Stats
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2016-2017 desde https://fbref.com/en/squads/361ca564/2016-2017/Tottenham-Hotspur-Stats
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2015-2016 desde https://fbref.com/en/squads/361ca564/2015-2016/Tottenham-Hotspur-Stats
# Descargando datos de scores_and_fixtures, Tottenham_Hotspur.2014-2015 desde https://fbref.com/en/squads/361ca564/2014-2015/Tottenham-Hotspur-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Manchester_United.2024-2025 desde https://fbref.com/en/squads/19538871/2024-2025/Manchester-United-Stats
# Descargando datos de scores_and_fixtures, Manchester_United.2023-2024 desde https://fbref.com/en/squads/19538871/2023-2024/Manchester-United-Stats
# Descargando datos de scores_and_fixtures, Manchester_United.2022-2023 desde https://fbref.com/en/squads/19538871/2022-2023/Manchester-United-Stats
# Descargando datos de scores_and_fixtures, Manchester_United.2021-2022 desde https://fbref.com/en/squads/19538871/2021-2022/Manchester-United-Stats
# Descargando datos de scores_and_fixtures, Manchester_United.2020-2021 desde https://fbref.com/en/squads/19538871/2020-2021/Manchester-United-Stats
# Descargando datos de scores_and_fixtures, Manchester_United.2019-2020 desde https://fbref.com/en/squads/19538871/2019-2020/Manchester-United-Stats
# Descargando datos de scores_and_fixtures, Manchester_United.2018-2019 desde https://fbref.com/en/squads/19538871/2018-2019/Manchester-United-Stats
# Descargando datos de scores_and_fixtures, Manchester_United.2017-2018 desde https://fbref.com/en/squads/19538871/2017-2018/Manchester-United-Stats
# Descargando datos de scores_and_fixtures, Manchester_United.2016-2017 desde https://fbref.com/en/squads/19538871/2016-2017/Manchester-United-Stats
# Descargando datos de scores_and_fixtures, Manchester_United.2015-2016 desde https://fbref.com/en/squads/19538871/2015-2016/Manchester-United-Stats
# Descargando datos de scores_and_fixtures, Manchester_United.2014-2015 desde https://fbref.com/en/squads/19538871/2014-2015/Manchester-United-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Brentford.2024-2025 desde https://fbref.com/en/squads/cd051869/2024-2025/Brentford-Stats
# Descargando datos de scores_and_fixtures, Brentford.2023-2024 desde https://fbref.com/en/squads/cd051869/2023-2024/Brentford-Stats
# Descargando datos de scores_and_fixtures, Brentford.2022-2023 desde https://fbref.com/en/squads/cd051869/2022-2023/Brentford-Stats
# Descargando datos de scores_and_fixtures, Brentford.2021-2022 desde https://fbref.com/en/squads/cd051869/2021-2022/Brentford-Stats
# Descargando datos de scores_and_fixtures, Brentford.2020-2021 desde https://fbref.com/en/squads/cd051869/2020-2021/Brentford-Stats
# Descargando datos de scores_and_fixtures, Brentford.2019-2020 desde https://fbref.com/en/squads/cd051869/2019-2020/Brentford-Stats
# Descargando datos de scores_and_fixtures, Brentford.2018-2019 desde https://fbref.com/en/squads/cd051869/2018-2019/Brentford-Stats
# Descargando datos de scores_and_fixtures, Brentford.2017-2018 desde https://fbref.com/en/squads/cd051869/2017-2018/Brentford-Stats
# Descargando datos de scores_and_fixtures, Brentford.2016-2017 desde https://fbref.com/en/squads/cd051869/2016-2017/Brentford-Stats
# Descargando datos de scores_and_fixtures, Brentford.2015-2016 desde https://fbref.com/en/squads/cd051869/2015-2016/Brentford-Stats
# Descargando datos de scores_and_fixtures, Brentford.2014-2015 desde https://fbref.com/en/squads/cd051869/2014-2015/Brentford-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Bournemouth.2024-2025 desde https://fbref.com/en/squads/4ba7cbea/2024-2025/Bournemouth-Stats
# Descargando datos de scores_and_fixtures, Bournemouth.2023-2024 desde https://fbref.com/en/squads/4ba7cbea/2023-2024/Bournemouth-Stats
# Descargando datos de scores_and_fixtures, Bournemouth.2022-2023 desde https://fbref.com/en/squads/4ba7cbea/2022-2023/Bournemouth-Stats
# Descargando datos de scores_and_fixtures, Bournemouth.2021-2022 desde https://fbref.com/en/squads/4ba7cbea/2021-2022/Bournemouth-Stats
# Descargando datos de scores_and_fixtures, Bournemouth.2020-2021 desde https://fbref.com/en/squads/4ba7cbea/2020-2021/Bournemouth-Stats
# Descargando datos de scores_and_fixtures, Bournemouth.2019-2020 desde https://fbref.com/en/squads/4ba7cbea/2019-2020/Bournemouth-Stats
# Descargando datos de scores_and_fixtures, Bournemouth.2018-2019 desde https://fbref.com/en/squads/4ba7cbea/2018-2019/Bournemouth-Stats
# Descargando datos de scores_and_fixtures, Bournemouth.2017-2018 desde https://fbref.com/en/squads/4ba7cbea/2017-2018/Bournemouth-Stats
# Descargando datos de scores_and_fixtures, Bournemouth.2016-2017 desde https://fbref.com/en/squads/4ba7cbea/2016-2017/Bournemouth-Stats
# Descargando datos de scores_and_fixtures, Bournemouth.2015-2016 desde https://fbref.com/en/squads/4ba7cbea/2015-2016/Bournemouth-Stats
# Descargando datos de scores_and_fixtures, Bournemouth.2014-2015 desde https://fbref.com/en/squads/4ba7cbea/2014-2015/Bournemouth-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, West_Ham_United.2024-2025 desde https://fbref.com/en/squads/7c21e445/2024-2025/West-Ham-United-Stats
# Descargando datos de scores_and_fixtures, West_Ham_United.2023-2024 desde https://fbref.com/en/squads/7c21e445/2023-2024/West-Ham-United-Stats
# Descargando datos de scores_and_fixtures, West_Ham_United.2022-2023 desde https://fbref.com/en/squads/7c21e445/2022-2023/West-Ham-United-Stats
# Descargando datos de scores_and_fixtures, West_Ham_United.2021-2022 desde https://fbref.com/en/squads/7c21e445/2021-2022/West-Ham-United-Stats
# Descargando datos de scores_and_fixtures, West_Ham_United.2020-2021 desde https://fbref.com/en/squads/7c21e445/2020-2021/West-Ham-United-Stats
# Descargando datos de scores_and_fixtures, West_Ham_United.2019-2020 desde https://fbref.com/en/squads/7c21e445/2019-2020/West-Ham-United-Stats
# Descargando datos de scores_and_fixtures, West_Ham_United.2018-2019 desde https://fbref.com/en/squads/7c21e445/2018-2019/West-Ham-United-Stats
# Descargando datos de scores_and_fixtures, West_Ham_United.2017-2018 desde https://fbref.com/en/squads/7c21e445/2017-2018/West-Ham-United-Stats
# Descargando datos de scores_and_fixtures, West_Ham_United.2016-2017 desde https://fbref.com/en/squads/7c21e445/2016-2017/West-Ham-United-Stats
# Descargando datos de scores_and_fixtures, West_Ham_United.2015-2016 desde https://fbref.com/en/squads/7c21e445/2015-2016/West-Ham-United-Stats
# Descargando datos de scores_and_fixtures, West_Ham_United.2014-2015 desde https://fbref.com/en/squads/7c21e445/2014-2015/West-Ham-United-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Leicester_City.2024-2025 desde https://fbref.com/en/squads/a2d435b3/2024-2025/Leicester-City-Stats
# Descargando datos de scores_and_fixtures, Leicester_City.2023-2024 desde https://fbref.com/en/squads/a2d435b3/2023-2024/Leicester-City-Stats
# Descargando datos de scores_and_fixtures, Leicester_City.2022-2023 desde https://fbref.com/en/squads/a2d435b3/2022-2023/Leicester-City-Stats
# Descargando datos de scores_and_fixtures, Leicester_City.2021-2022 desde https://fbref.com/en/squads/a2d435b3/2021-2022/Leicester-City-Stats
# Descargando datos de scores_and_fixtures, Leicester_City.2020-2021 desde https://fbref.com/en/squads/a2d435b3/2020-2021/Leicester-City-Stats
# Descargando datos de scores_and_fixtures, Leicester_City.2019-2020 desde https://fbref.com/en/squads/a2d435b3/2019-2020/Leicester-City-Stats
# Descargando datos de scores_and_fixtures, Leicester_City.2018-2019 desde https://fbref.com/en/squads/a2d435b3/2018-2019/Leicester-City-Stats
# Descargando datos de scores_and_fixtures, Leicester_City.2017-2018 desde https://fbref.com/en/squads/a2d435b3/2017-2018/Leicester-City-Stats
# Descargando datos de scores_and_fixtures, Leicester_City.2016-2017 desde https://fbref.com/en/squads/a2d435b3/2016-2017/Leicester-City-Stats
# Descargando datos de scores_and_fixtures, Leicester_City.2015-2016 desde https://fbref.com/en/squads/a2d435b3/2015-2016/Leicester-City-Stats
# Descargando datos de scores_and_fixtures, Leicester_City.2014-2015 desde https://fbref.com/en/squads/a2d435b3/2014-2015/Leicester-City-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Crystal_Palace.2024-2025 desde https://fbref.com/en/squads/47c64c55/2024-2025/Crystal-Palace-Stats
# Descargando datos de scores_and_fixtures, Crystal_Palace.2023-2024 desde https://fbref.com/en/squads/47c64c55/2023-2024/Crystal-Palace-Stats
# Descargando datos de scores_and_fixtures, Crystal_Palace.2022-2023 desde https://fbref.com/en/squads/47c64c55/2022-2023/Crystal-Palace-Stats
# Descargando datos de scores_and_fixtures, Crystal_Palace.2021-2022 desde https://fbref.com/en/squads/47c64c55/2021-2022/Crystal-Palace-Stats
# Descargando datos de scores_and_fixtures, Crystal_Palace.2020-2021 desde https://fbref.com/en/squads/47c64c55/2020-2021/Crystal-Palace-Stats
# Descargando datos de scores_and_fixtures, Crystal_Palace.2019-2020 desde https://fbref.com/en/squads/47c64c55/2019-2020/Crystal-Palace-Stats
# Descargando datos de scores_and_fixtures, Crystal_Palace.2018-2019 desde https://fbref.com/en/squads/47c64c55/2018-2019/Crystal-Palace-Stats
# Descargando datos de scores_and_fixtures, Crystal_Palace.2017-2018 desde https://fbref.com/en/squads/47c64c55/2017-2018/Crystal-Palace-Stats
# Descargando datos de scores_and_fixtures, Crystal_Palace.2016-2017 desde https://fbref.com/en/squads/47c64c55/2016-2017/Crystal-Palace-Stats
# Descargando datos de scores_and_fixtures, Crystal_Palace.2015-2016 desde https://fbref.com/en/squads/47c64c55/2015-2016/Crystal-Palace-Stats
# Descargando datos de scores_and_fixtures, Crystal_Palace.2014-2015 desde https://fbref.com/en/squads/47c64c55/2014-2015/Crystal-Palace-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Ipswic_Town.2024-2025 desde https://fbref.com/en/squads/b74092de/2024-2025/Ipswich-Town-Stats
# Descargando datos de scores_and_fixtures, Ipswic_Town.2023-2024 desde https://fbref.com/en/squads/b74092de/2023-2024/Ipswich-Town-Stats
# Descargando datos de scores_and_fixtures, Ipswic_Town.2022-2023 desde https://fbref.com/en/squads/b74092de/2022-2023/Ipswich-Town-Stats
# Descargando datos de scores_and_fixtures, Ipswic_Town.2021-2022 desde https://fbref.com/en/squads/b74092de/2021-2022/Ipswich-Town-Stats
# Descargando datos de scores_and_fixtures, Ipswic_Town.2020-2021 desde https://fbref.com/en/squads/b74092de/2020-2021/Ipswich-Town-Stats
# Descargando datos de scores_and_fixtures, Ipswic_Town.2019-2020 desde https://fbref.com/en/squads/b74092de/2019-2020/Ipswich-Town-Stats
# Descargando datos de scores_and_fixtures, Ipswic_Town.2018-2019 desde https://fbref.com/en/squads/b74092de/2018-2019/Ipswich-Town-Stats
# Descargando datos de scores_and_fixtures, Ipswic_Town.2017-2018 desde https://fbref.com/en/squads/b74092de/2017-2018/Ipswich-Town-Stats
# Descargando datos de scores_and_fixtures, Ipswic_Town.2016-2017 desde https://fbref.com/en/squads/b74092de/2016-2017/Ipswich-Town-Stats
# Descargando datos de scores_and_fixtures, Ipswic_Town.2015-2016 desde https://fbref.com/en/squads/b74092de/2015-2016/Ipswich-Town-Stats
# Descargando datos de scores_and_fixtures, Ipswic_Town.2014-2015 desde https://fbref.com/en/squads/b74092de/2014-2015/Ipswich-Town-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Southampton.2024-2025 desde https://fbref.com/en/squads/33c895d4/2024-2025/Southampton-Stats
# Descargando datos de scores_and_fixtures, Southampton.2023-2024 desde https://fbref.com/en/squads/33c895d4/2023-2024/Southampton-Stats
# Descargando datos de scores_and_fixtures, Southampton.2022-2023 desde https://fbref.com/en/squads/33c895d4/2022-2023/Southampton-Stats
# Descargando datos de scores_and_fixtures, Southampton.2021-2022 desde https://fbref.com/en/squads/33c895d4/2021-2022/Southampton-Stats
# Descargando datos de scores_and_fixtures, Southampton.2020-2021 desde https://fbref.com/en/squads/33c895d4/2020-2021/Southampton-Stats
# Descargando datos de scores_and_fixtures, Southampton.2019-2020 desde https://fbref.com/en/squads/33c895d4/2019-2020/Southampton-Stats
# Descargando datos de scores_and_fixtures, Southampton.2018-2019 desde https://fbref.com/en/squads/33c895d4/2018-2019/Southampton-Stats
# Descargando datos de scores_and_fixtures, Southampton.2017-2018 desde https://fbref.com/en/squads/33c895d4/2017-2018/Southampton-Stats
# Descargando datos de scores_and_fixtures, Southampton.2016-2017 desde https://fbref.com/en/squads/33c895d4/2016-2017/Southampton-Stats
# Descargando datos de scores_and_fixtures, Southampton.2015-2016 desde https://fbref.com/en/squads/33c895d4/2015-2016/Southampton-Stats
# Descargando datos de scores_and_fixtures, Southampton.2014-2015 desde https://fbref.com/en/squads/33c895d4/2014-2015/Southampton-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Everton.2024-2025 desde https://fbref.com/en/squads/d3fd31cc/2024-2025/Everton-Stats
# Descargando datos de scores_and_fixtures, Everton.2023-2024 desde https://fbref.com/en/squads/d3fd31cc/2023-2024/Everton-Stats
# Descargando datos de scores_and_fixtures, Everton.2022-2023 desde https://fbref.com/en/squads/d3fd31cc/2022-2023/Everton-Stats
# Descargando datos de scores_and_fixtures, Everton.2021-2022 desde https://fbref.com/en/squads/d3fd31cc/2021-2022/Everton-Stats
# Descargando datos de scores_and_fixtures, Everton.2020-2021 desde https://fbref.com/en/squads/d3fd31cc/2020-2021/Everton-Stats
# Descargando datos de scores_and_fixtures, Everton.2019-2020 desde https://fbref.com/en/squads/d3fd31cc/2019-2020/Everton-Stats
# Descargando datos de scores_and_fixtures, Everton.2018-2019 desde https://fbref.com/en/squads/d3fd31cc/2018-2019/Everton-Stats
# Descargando datos de scores_and_fixtures, Everton.2017-2018 desde https://fbref.com/en/squads/d3fd31cc/2017-2018/Everton-Stats
# Descargando datos de scores_and_fixtures, Everton.2016-2017 desde https://fbref.com/en/squads/d3fd31cc/2016-2017/Everton-Stats
# Descargando datos de scores_and_fixtures, Everton.2015-2016 desde https://fbref.com/en/squads/d3fd31cc/2015-2016/Everton-Stats
# Descargando datos de scores_and_fixtures, Everton.2014-2015 desde https://fbref.com/en/squads/d3fd31cc/2014-2015/Everton-Stats
# Procesando base de datos:
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2024-2025 desde https://fbref.com/en/squads/8cec06e1/2024-2025/Wolverhampton-Wanderers-Stats
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2023-2024 desde https://fbref.com/en/squads/8cec06e1/2023-2024/Wolverhampton-Wanderers-Stats
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2022-2023 desde https://fbref.com/en/squads/8cec06e1/2022-2023/Wolverhampton-Wanderers-Stats
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2021-2022 desde https://fbref.com/en/squads/8cec06e1/2021-2022/Wolverhampton-Wanderers-Stats
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2020-2021 desde https://fbref.com/en/squads/8cec06e1/2020-2021/Wolverhampton-Wanderers-Stats
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2019-2020 desde https://fbref.com/en/squads/8cec06e1/2019-2020/Wolverhampton-Wanderers-Stats
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2018-2019 desde https://fbref.com/en/squads/8cec06e1/2018-2019/Wolverhampton-Wanderers-Stats
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2017-2018 desde https://fbref.com/en/squads/8cec06e1/2017-2018/Wolverhampton-Wanderers-Stats
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2016-2017 desde https://fbref.com/en/squads/8cec06e1/2016-2017/Wolverhampton-Wanderers-Stats
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2015-2016 desde https://fbref.com/en/squads/8cec06e1/2015-2016/Wolverhampton-Wanderers-Stats
# Descargando datos de scores_and_fixtures, Wolverhampton_Wanderers.2014-2015 desde https://fbref.com/en/squads/8cec06e1/2014-2015/Wolverhampton-Wanderers-Stats

# %%
# retrieved_data = data_cleaning(retrieved_data)
# retrieved_data = add_columns(retrieved_data)

print(retrieved_data.columns)
print(retrieved_data.shape)

# db_path = "data/sqldata/Historic_scores_and_fixtures.db"

# conn = sqlite3.connect(db_path)

# current_total_data = pd.read_sql_query("SELECT * FROM scores_and_fixture", conn)
# # current_total_data = pd.read_csv('data/csvdata/scores_and_fixtures.csv')
# current_total_data = current_total_data[~current_total_data.Temporada.isin([season])]

# new_data = pd.concat([current_total_data, retrieved_data], ignore_index=True, sort=False)
# new_data.to_sql('scores_and_fixture', conn, if_exists='replace', index=False)
# new_data.to_csv('data/csvdata/scores_and_fixtures.csv')
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Opp Formation', 'Referee', 'Match Report', 'Notes', 'Temporada',
#        'MetaEquipo'],
#       dtype='object')
# (6167, 22)
